# %% [markdown]
# Mounting Google Drive in Notebook

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Importing pandas library and Loading "Bake Sale" data

# %%
#import pandas
import pandas as pd

#save filepath
file_path = "/content/drive/MyDrive/Coding_Dojo_Data_Science_Excercises/02_Pandas_for_Data_Manipulation/data/Our Bake Sale [Loading Data Vers] - Day 4 Sales.csv"

# load in the data as a pandas dataframe
df = pd.read_csv(file_path)

# %% [markdown]
# Checking if dataframe loaded correctly using .head() and .info()

# %%
df.head()
# Out:
#       Item  Student                        Packaging  Price  Expense  \
# 0  brownie     Hugo  Individually Wrapped  (Plastic)   2.25     0.25
# 1   cookie    Sally  Individually Wrapped  (Plastic)   1.25     0.50
# 2     cake  Martina            Boxed (Clear Plastic)   9.50     5.00
# 3  cupcake      Joe                Boxed (Cardboard)   3.50     0.75
# 4    fudge     Hugo      Individually Wrapped (Foil)   3.00     1.00
#
#    Quantity Sold (Day 1)  Quantity Sold (Day 2)  Quantity Sold (Day 3)  \
# 0                     17                     19                     25
# 1                     40                     32                     38
# 2                      1                      2                      0
# 3                     10                     14                     12
# 4                      0                     20                     22
#
#    Quantity Sold (Day 4)
# 0                     25
# 1                     38
# 2                      0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Item                   12 non-null     object
#  1   Student                12 non-null     object
#  2   Packaging              12 non-null     object
#  3   Price                  12 non-null     float64
#  4   Expense                12 non-null     float64
#  5   Quantity Sold (Day 1)  12 non-null     int64
#  6   Quantity Sold (Day 2)  12 non-null     int64
#  7   Quantity Sold (Day 3)  12 non-null     int64
#  8   Quantity Sold (Day 4)  12 non-null     int64
# dtypes: float64(2), int64(4), object(3)
# memory usage: 992.0+ bytes

# %% [markdown]
# Calculate 'Profit per Item' and add that calculation after 'Expense' Column

# %%
profit_per_item = df['Price'] - df['Expense']
# Insert the new column
df.insert(5, 'Profit per Item', profit_per_item )
# Verify the result
df.head()
# Out:
#       Item  Student                        Packaging  Price  Expense  \
# 0  brownie     Hugo  Individually Wrapped  (Plastic)   2.25     0.25
# 1   cookie    Sally  Individually Wrapped  (Plastic)   1.25     0.50
# 2     cake  Martina            Boxed (Clear Plastic)   9.50     5.00
# 3  cupcake      Joe                Boxed (Cardboard)   3.50     0.75
# 4    fudge     Hugo      Individually Wrapped (Foil)   3.00     1.00
#
#    Profit per Item  Quantity Sold (Day 1)  Quantity Sold (Day 2)  \
# 0             2.00                     17                     19
# 1             0.75                     40                     32
# 2             4.50                      1                      2
# 3             2.75                     10                     14
# 4             2.00                      0                     20
#
#    Quantity Sold (Day 3)  Quantity Sold (Day 4)
# 0                     25                     25
# 1                     38                     38
# ...

# %% [markdown]
# Save new dataframe created in new csv file called 'bake-sale-data-with-profit-per-item.csv'

# %%
file_path_out = "/content/drive/MyDrive/Coding_Dojo_Data_Science_Excercises/02_Pandas_for_Data_Manipulation/data/bake-sale-data-with-profit-per-item.csv"
df.to_csv(file_path_out, index=False)
